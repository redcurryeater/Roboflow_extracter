# %%
import torch
from yolov5 import utils 
display = utils.notebook_init()
# Out:
# YOLOv5  torch 1.11.0 CPU
# Setup complete  (6 CPUs, 15.9 GB RAM, 344.3/465.2 GB disk)

# %%
# %pip install -q wandb
import wandb
wandb.login()
# Out:
# Note: you may need to restart the kernel to use updated packages.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit: ········
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\julie/.netrc
# True

# %%
# !python yolov5\train.py --img 128 --batch 32 --epochs 3 --data C:\Users\julie\movement_stop\data\cards_dataset\data.yaml --weights yolov5s.pt --cache
# Out:
# wandb: Currently logged in as: juliens. Use `wandb login --relogin` to force relogin
# train: weights=yolov5s.pt, cfg=, data=C:\Users\julie\movement_stop\data\cards_dataset\data.yaml, hyp=yolov5\data\hyps\hyp.scratch-low.yaml, epochs=3, batch_size=32, imgsz=128, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5\runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v6.1-253-g75bbaa8 Python-3.9.12 torch-1.11.0 CPU
#
# ...
